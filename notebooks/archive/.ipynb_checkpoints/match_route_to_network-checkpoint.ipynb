# %%
import geopandas as gpd
import numpy as npm
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from shapely.geometry import Point
from shapely.geometry import LineString
from shapely.geometry import MultiLineString
from collections import deque

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
CRS_PLOT = 'EPSG:4326'
DATA_DIR = '../data'
EXPORTS_DIR = f'{DATA_DIR}/exports'

zips_gdf = gpd.read_file(f'{EXPORTS_DIR}/zips_bk.shp').to_crs({'init': CRS_PLOT})
lion_nodes_gdf = gpd.read_file(f'{DATA_DIR}/lion_nodes_bk.geojson').to_crs({'init': CRS_PLOT})
edges_df = pd.read_csv(f'{EXPORTS_DIR}/edges_bk.csv')
edges_df['nodes_to'] = edges_df['nodes_to'].apply(lambda x: eval(x))

# %%
stops_df = pd.read_csv(f'{DATA_DIR}/gtfs_20210428/stops.txt')
stop_times_df = pd.read_csv(f'{DATA_DIR}/gtfs_20210428/stop_times.txt')

# %%
route_stop_times_df = stop_times_df[stop_times_df['trip_id'] == 'EN_B1-Weekday-076700_B25_220']
route_stop_times_df
# Out:
#                             trip_id arrival_time departure_time  stop_id  \
# 64137  EN_B1-Weekday-076700_B25_220     12:47:00       12:47:00   308626
# 64138  EN_B1-Weekday-076700_B25_220     12:48:13       12:48:13   308025
# 64139  EN_B1-Weekday-076700_B25_220     12:50:05       12:50:05   302355
# 64140  EN_B1-Weekday-076700_B25_220     12:50:46       12:50:46   306437
# 64141  EN_B1-Weekday-076700_B25_220     12:51:37       12:51:37   302356
# 64142  EN_B1-Weekday-076700_B25_220     12:52:37       12:52:37   302357
# 64143  EN_B1-Weekday-076700_B25_220     12:53:21       12:53:21   302359
# 64144  EN_B1-Weekday-076700_B25_220     12:54:20       12:54:20   302358
# 64145  EN_B1-Weekday-076700_B25_220     12:55:00       12:55:00   303011
# 64146  EN_B1-Weekday-076700_B25_220     12:59:58       12:59:58   307460
# 64147  EN_B1-Weekday-076700_B25_220     13:01:54       13:01:54   302945
# 64148  EN_B1-Weekday-076700_B25_220     13:03:44       13:03:44   307491
# 64149  EN_B1-Weekday-076700_B25_220     13:06:00       13:06:00   302947
# 64150  EN_B1-Weekday-076700_B25_220     13:08:56       13:08:56   303017
# 64151  EN_B1-Weekday-076700_B25_220     13:10:41       13:10:41   302368
# 64152  EN_B1-Weekday-076700_B25_220     13:12:38       13:12:38   302369
# 64153  EN_B1-Weekday-076700_B25_220     13:15:00       13:15:00   302370
# 64154  EN_B1-Weekday-076700_B25_220     13:16:32       13:16:32   302371
# 64155  EN_B1-Weekday-076700_B25_220     13:17:52       13:17:52   302372
# 64156  EN_B1-Weekday-076700_B25_220     13:19:19       13:19:19   302374
# 64157  EN_B1-Weekday-076700_B25_220     13:19:59       13:19:59   302375
# 64158  EN_B1-Weekday-076700_B25_220     13:20:56       13:20:56   302376
# 64159  EN_B1-Weekday-076700_B25_220     13:23:19       13:23:19   302377
# 64160  EN_B1-Weekday-076700_B25_220     13:25:09       13:25:09   302378
# 64161  EN_B1-Weekday-076700_B25_220     13:26:44       13:26:44   302379
# 64162  EN_B1-Weekday-076700_B25_220     13:29:00       13:29:00   302380
# 64163  EN_B1-Weekday-076700_B25_220     13:30:53       13:30:53   302381
# 64164  EN_B1-Weekday-076700_B25_220     13:31:41       13:31:41   302382
# 64165  EN_B1-Weekday-076700_B25_220     13:33:11       13:33:11   302383
# 64166  EN_B1-Weekday-076700_B25_220     13:35:14       13:35:14   307926
# 64167  EN_B1-Weekday-076700_B25_220     13:36:54       13:36:54   307251
# 64168  EN_B1-Weekday-076700_B25_220     13:37:57       13:37:57   307252
# 64169  EN_B1-Weekday-076700_B25_220     13:40:02       13:40:02   307253
# 64170  EN_B1-Weekday-076700_B25_220     13:42:28       13:42:28   307254
# 64171  EN_B1-Weekday-076700_B25_220     13:44:00       13:44:00   307255
# 64172  EN_B1-Weekday-076700_B25_220     13:45:35       13:45:35   307256
# 64173  EN_B1-Weekday-076700_B25_220     13:47:10       13:47:10   307257
# 64174  EN_B1-Weekday-076700_B25_220     13:48:48       13:48:48   307259
# 64175  EN_B1-Weekday-076700_B25_220     13:50:27       13:50:27   307260
# 64176  EN_B1-Weekday-076700_B25_220     13:51:44       13:51:44   307631
# 64177  EN_B1-Weekday-076700_B25_220     13:54:29       13:54:29   307263
# 64178  EN_B1-Weekday-076700_B25_220     13:57:00       13:57:00   901211
#
#        stop_sequence  pickup_type  drop_off_type
# 64137              1            0              0
# 64138              2            0              0
# 64139              3            0              0
# 64140              4            0              0
# 64141              5            0              0
# 64142              6            0              0
# 64143              7            0              0
# 64144              8            0              0
# 64145              9            0              0
# 64146             10            0              0
# 64147             11            0              0
# 64148             12            0              0
# 64149             13            0              0
# 64150             14            0              0
# 64151             15            0              0
# 64152             16            0              0
# 64153             17            0              0
# 64154             18            0              0
# 64155             19            0              0
# 64156             20            0              0
# 64157             21            0              0
# 64158             22            0              0
# 64159             23            0              0
# 64160             24            0              0
# 64161             25            0              0
# 64162             26            0              0
# 64163             27            0              0
# 64164             28            0              0
# 64165             29            0              0
# 64166             30            0              0
# 64167             31            0              0
# 64168             32            0              0
# 64169             33            0              0
# 64170             34            0              0
# 64171             35            0              0
# 64172             36            0              0
# 64173             37            0              0
# 64174             38            0              0
# 64175             39            0              0
# 64176             40            0              0
# 64177             41            0              0
# 64178             42            0              0

# %%
stop_times_df['arrival_time'] = pd.to_datetime(stop_times_df['arrival_time'], format='%H:%M:%S', errors='coerce')
stop_times_df['departure_time'] = pd.to_datetime(stop_times_df['departure_time'], format='%H:%M:%S', errors='coerce')

st_df = stop_times_df
st_df = st_df[st_df['trip_id'].str.contains('_B25')]
st_df = st_df[st_df['trip_id'].str.contains('Weekday')]
st_df = st_df[st_df['stop_sequence'] == 39]
st_df = st_df[st_df['arrival_time'] > datetime.datetime.strptime('1900-01-01 13:50:00', '%Y-%m-%d %H:%M:%S')]
st_df = st_df[st_df['arrival_time'] < datetime.datetime.strptime('1900-01-01 14:20:00', '%Y-%m-%d %H:%M:%S')]
st_df = st_df.sort_values(by=['arrival_time', 'trip_id'])
st_df
# Out:
#                                    trip_id        arrival_time  \
# 64175         EN_B1-Weekday-076700_B25_220 1900-01-01 13:50:27
# 1543503  EN_B1-Weekday-SDon-076700_B25_220 1900-01-01 13:50:27
# 60692         EN_B1-Weekday-077500_B25_222 1900-01-01 13:58:27
# 1540020  EN_B1-Weekday-SDon-077500_B25_222 1900-01-01 13:58:27
# 59438         EN_B1-Weekday-077900_B25_207 1900-01-01 13:59:00
# 1538766  EN_B1-Weekday-SDon-077900_B25_207 1900-01-01 13:59:00
# 28116         EN_B1-Weekday-080300_B25_205 1900-01-01 14:11:34
# 1507444  EN_B1-Weekday-SDon-080300_B25_205 1900-01-01 14:11:34
# 61340         EN_B1-Weekday-079000_B25_223 1900-01-01 14:13:27
# 1540668  EN_B1-Weekday-SDon-079000_B25_223 1900-01-01 14:13:27
# 64460         EN_B1-Weekday-079600_B25_221 1900-01-01 14:16:00
# 1543788  EN_B1-Weekday-SDon-079600_B25_221 1900-01-01 14:16:00
#
#              departure_time  stop_id  stop_sequence  pickup_type  \
# 64175   1900-01-01 13:50:27   307260             39            0
# 1543503 1900-01-01 13:50:27   307260             39            0
# 60692   1900-01-01 13:58:27   307260             39            0
# 1540020 1900-01-01 13:58:27   307260             39            0
# 59438   1900-01-01 13:59:00   801071             39            0
# 1538766 1900-01-01 13:59:00   801071             39            0
# 28116   1900-01-01 14:11:34   301056             39            0
# 1507444 1900-01-01 14:11:34   301056             39            0
# 61340   1900-01-01 14:13:27   307260             39            0
# 1540668 1900-01-01 14:13:27   307260             39            0
# 64460   1900-01-01 14:16:00   801071             39            0
# 1543788 1900-01-01 14:16:00   801071             39            0
#
#          drop_off_type
# 64175                0
# 1543503              0
# 60692                0
# 1540020              0
# 59438                0
# 1538766              0
# 28116                0
# 1507444              0
# 61340                0
# 1540668              0
# 64460                0
# 1543788              0

# %%
df1 = stop_times_df[stop_times_df['trip_id'].str.contains('B25')].groupby(['trip_id']).agg({'arrival_time': 'first'})
df1.iloc[300:310]
# Out:
#                              arrival_time
# trip_id
# EN_B1-Weekday-038800_B25_208     06:28:00
# EN_B1-Weekday-039200_B25_204     06:32:00
# EN_B1-Weekday-040000_B25_201     06:40:00
# EN_B1-Weekday-040200_B25_210     06:42:00
# EN_B1-Weekday-041200_B25_205     06:52:00
# EN_B1-Weekday-041200_B25_211     06:52:00
# EN_B1-Weekday-041600_B25_212     06:56:00
# EN_B1-Weekday-042000_B25_207     07:00:00
# EN_B1-Weekday-042200_B25_213     07:02:00
# EN_B1-Weekday-042900_B25_206     07:09:00

# %%
route_df = pd.merge(route_stop_times_df, stops_df, on='stop_id', how='left')
route_df
# Out:
#                          trip_id arrival_time departure_time  stop_id  \
# 0   EN_B1-Weekday-076700_B25_220     12:47:00       12:47:00   308626
# 1   EN_B1-Weekday-076700_B25_220     12:48:13       12:48:13   308025
# 2   EN_B1-Weekday-076700_B25_220     12:50:05       12:50:05   302355
# 3   EN_B1-Weekday-076700_B25_220     12:50:46       12:50:46   306437
# 4   EN_B1-Weekday-076700_B25_220     12:51:37       12:51:37   302356
# 5   EN_B1-Weekday-076700_B25_220     12:52:37       12:52:37   302357
# 6   EN_B1-Weekday-076700_B25_220     12:53:21       12:53:21   302359
# 7   EN_B1-Weekday-076700_B25_220     12:54:20       12:54:20   302358
# 8   EN_B1-Weekday-076700_B25_220     12:55:00       12:55:00   303011
# 9   EN_B1-Weekday-076700_B25_220     12:59:58       12:59:58   307460
# 10  EN_B1-Weekday-076700_B25_220     13:01:54       13:01:54   302945
# 11  EN_B1-Weekday-076700_B25_220     13:03:44       13:03:44   307491
# 12  EN_B1-Weekday-076700_B25_220     13:06:00       13:06:00   302947
# 13  EN_B1-Weekday-076700_B25_220     13:08:56       13:08:56   303017
# 14  EN_B1-Weekday-076700_B25_220     13:10:41       13:10:41   302368
# 15  EN_B1-Weekday-076700_B25_220     13:12:38       13:12:38   302369
# 16  EN_B1-Weekday-076700_B25_220     13:15:00       13:15:00   302370
# 17  EN_B1-Weekday-076700_B25_220     13:16:32       13:16:32   302371
# 18  EN_B1-Weekday-076700_B25_220     13:17:52       13:17:52   302372
# 19  EN_B1-Weekday-076700_B25_220     13:19:19       13:19:19   302374
# 20  EN_B1-Weekday-076700_B25_220     13:19:59       13:19:59   302375
# 21  EN_B1-Weekday-076700_B25_220     13:20:56       13:20:56   302376
# 22  EN_B1-Weekday-076700_B25_220     13:23:19       13:23:19   302377
# 23  EN_B1-Weekday-076700_B25_220     13:25:09       13:25:09   302378
# 24  EN_B1-Weekday-076700_B25_220     13:26:44       13:26:44   302379
# 25  EN_B1-Weekday-076700_B25_220     13:29:00       13:29:00   302380
# 26  EN_B1-Weekday-076700_B25_220     13:30:53       13:30:53   302381
# 27  EN_B1-Weekday-076700_B25_220     13:31:41       13:31:41   302382
# 28  EN_B1-Weekday-076700_B25_220     13:33:11       13:33:11   302383
# 29  EN_B1-Weekday-076700_B25_220     13:35:14       13:35:14   307926
# 30  EN_B1-Weekday-076700_B25_220     13:36:54       13:36:54   307251
# 31  EN_B1-Weekday-076700_B25_220     13:37:57       13:37:57   307252
# 32  EN_B1-Weekday-076700_B25_220     13:40:02       13:40:02   307253
# 33  EN_B1-Weekday-076700_B25_220     13:42:28       13:42:28   307254
# 34  EN_B1-Weekday-076700_B25_220     13:44:00       13:44:00   307255
# 35  EN_B1-Weekday-076700_B25_220     13:45:35       13:45:35   307256
# 36  EN_B1-Weekday-076700_B25_220     13:47:10       13:47:10   307257
# 37  EN_B1-Weekday-076700_B25_220     13:48:48       13:48:48   307259
# 38  EN_B1-Weekday-076700_B25_220     13:50:27       13:50:27   307260
# 39  EN_B1-Weekday-076700_B25_220     13:51:44       13:51:44   307631
# 40  EN_B1-Weekday-076700_B25_220     13:54:29       13:54:29   307263
# 41  EN_B1-Weekday-076700_B25_220     13:57:00       13:57:00   901211
#
#     stop_sequence  pickup_type  drop_off_type                      stop_name  \
# 0               1            0              0             FRONT ST / YORK ST
# 1               2            0              0               WATER ST/MAIN ST
# 2               3            0              0     OLD FULTON ST/ELIZABETH PL
# 3               4            0              0         OLD FULTON ST/HICKS ST
# 4               5            0              0         OLD FULTON ST/HENRY ST
# 5               6            0              0         CADMAN PZ W/MIDDAGH ST
# 6               7            0              0      CADMAN PLZ W/CADMAN TOWER
# 7               8            0              0           CADMAN PZ W/CLARK ST
# 8               9            0              0         TILLARY ST/CADMAN PZ E
# 9              10            0              0     ADAMS ST/BKLYN SUPREME CRT
# 10             11            0              0             FULTON ST/SMITH ST
# 11             12            0              0              FULTON ST/HOYT ST
# 12             13            0              0              FULTON ST/BOND ST
# 13             14            0              0          FULTON ST/ROCKWELL PL
# 14             15            0              0         FULTON ST/LAFAYETTE AV
# 15             16            0              0        FULTON ST/S PORTLAND AV
# 16             17            0              0           FULTON ST/CARLTON AV
# 17             18            0              0          FULTON ST/CLERMONT AV
# 18             19            0              0           FULTON ST/CLINTON AV
# 19             20            0              0        FULTON ST/WASHINGTON AV
# 20             21            0              0          FULTON ST/ST JAMES PL
# 21             22            0              0            FULTON ST/GRAND  AV
# 22             23            0              0           FULTON ST/CLASSON AV
# 23             24            0              0          FULTON ST/FRANKLIN AV
# 24             25            0              0           FULTON ST/BEDFORD AV
# 25             26            0              0          FULTON ST/NOSTRAND AV
# 26             27            0              0             FULTON ST/MARCY AV
# 27             28            0              0          FULTON ST/BROOKLYN AV
# 28             29            0              0          FULTON ST/KINGSTON AV
# 29             30            0              0            FULTON ST/ALBANY AV
# 30             31            0              0              FULTON ST/TROY AV
# 31             32            0              0       FULTON ST/SCHENECTADY AV
# 32             33            0              0             FULTON ST/UTICA AV
# 33             34            0              0           FULTON ST/BUFFALO AV
# 34             35            0              0             FULTON ST/RALPH AV
# 35             36            0              0            FULTON ST/HOWARD AV
# 36             37            0              0          FULTON ST/SARATOGA AV
# 37             38            0              0  FULTON ST/THOMAS S BOYLAND ST
# 38             39            0              0          FULTON ST/ROCKAWAY AV
# 39             40            0              0           FULTON ST/EASTERN PY
# 40             41            0              0      FULTON ST/VAN SINDEREN AV
# 41             42            0              0    EAST NEW YORK AV/ALABAMA AV
#
#     stop_desc   stop_lat   stop_lon  zone_id  stop_url  location_type  \
# 0         NaN  40.702514 -73.991915      NaN       NaN              0
# 1         NaN  40.703318 -73.991102      NaN       NaN              0
# 2         NaN  40.702666 -73.993952      NaN       NaN              0
# 3         NaN  40.702029 -73.992747      NaN       NaN              0
# 4         NaN  40.701021 -73.991449      NaN       NaN              0
# 5         NaN  40.699591 -73.991290      NaN       NaN              0
# 6         NaN  40.698348 -73.991565      NaN       NaN              0
# 7         NaN  40.696696 -73.991464      NaN       NaN              0
# 8         NaN  40.696104 -73.990366      NaN       NaN              0
# 9         NaN  40.692560 -73.989131      NaN       NaN              0
# 10        NaN  40.691480 -73.987534      NaN       NaN              0
# 11        NaN  40.690690 -73.985547      NaN       NaN              0
# 12        NaN  40.689709 -73.983099      NaN       NaN              0
# 13        NaN  40.688106 -73.979087      NaN       NaN              0
# 14        NaN  40.687146 -73.976690      NaN       NaN              0
# 15        NaN  40.686059 -73.974034      NaN       NaN              0
# 16        NaN  40.684780 -73.970798      NaN       NaN              0
# 17        NaN  40.683904 -73.968617      NaN       NaN              0
# 18        NaN  40.683332 -73.966593      NaN       NaN              0
# 19        NaN  40.682882 -73.964338      NaN       NaN              0
# 20        NaN  40.682662 -73.963300      NaN       NaN              0
# 21        NaN  40.682362 -73.961824      NaN       NaN              0
# 22        NaN  40.681579 -73.958134      NaN       NaN              0
# 23        NaN  40.680982 -73.955289      NaN       NaN              0
# 24        NaN  40.680500 -73.952805      NaN       NaN              0
# 25        NaN  40.680301 -73.949161      NaN       NaN              0
# 26        NaN  40.680116 -73.945667      NaN       NaN              0
# 27        NaN  40.680033 -73.944167      NaN       NaN              0
# 28        NaN  40.679880 -73.941381      NaN       NaN              0
# 29        NaN  40.679664 -73.937573      NaN       NaN              0
# 30        NaN  40.679501 -73.934459      NaN       NaN              0
# 31        NaN  40.679398 -73.932497      NaN       NaN              0
# 32        NaN  40.679190 -73.928636      NaN       NaN              0
# 33        NaN  40.678940 -73.924108      NaN       NaN              0
# 34        NaN  40.678762 -73.921250      NaN       NaN              0
# 35        NaN  40.678615 -73.918564      NaN       NaN              0
# 36        NaN  40.678489 -73.915892      NaN       NaN              0
# 37        NaN  40.678336 -73.913138      NaN       NaN              0
# 38        NaN  40.678189 -73.910359      NaN       NaN              0
# 39        NaN  40.678066 -73.908188      NaN       NaN              0
# 40        NaN  40.677816 -73.903542      NaN       NaN              0
# 41        NaN  40.676719 -73.900118      NaN       NaN              0
#
#     parent_station
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# 30             NaN
# 31             NaN
# 32             NaN
# 33             NaN
# 34             NaN
# 35             NaN
# 36             NaN
# 37             NaN
# 38             NaN
# 39             NaN
# 40             NaN
# 41             NaN

# %%
route_gdf = gpd.GeoDataFrame(route_df, geometry=gpd.points_from_xy(route_df['stop_lon'], route_df['stop_lat']), crs=CRS_PLOT)
route_gdf.to_file(f'{EXPORTS_DIR}/b25_220.shp')

# %%
nodes_set = set()
for i in range(0, len(edges_df)):
    node_id = edges_df.iloc[i, 0]
    nodes_set.add(node_id)
    
for i in range(0, len(edges_df)):
    node_id = edges_df.iloc[i, 0]
    nodes_set.add(node_id)

# %%
class Node:
    def __init__(self, id):
        self.id = id
        self.edges = set()
        row = lion_nodes_gdf[lion_nodes_gdf['NODEID'] == id]
        
        self.lat = list(row.geometry)[0][0].y
        self.lon = list(row.geometry)[0][0].x
        
        self.point = Point(self.lon, self.lat)
        
    def add_neighbor(self, node):
        edge = Edge(self, node)
        self.edges.add(edge)
        return edge
        
class Edge:
    def __init__(self, node_from, node_to):
        self.node_from = node_from
        self.node_to = node_to
        self.key = f'{node_from.id}:{node_to.id}'
        self.line_string = LineString([node_from.point, node_to.point])

# %%
nodes_dict = {}

for i in range(0, len(edges_df)):
    node_id = edges_df.iloc[i, 0]
    nodes_dict[node_id] = Node(node_id)

# %%
edges_dict = {}

for i in range(0, len(edges_df)):
    node_id = edges_df.iloc[i, 0]
    neighbor_ids = edges_df.iloc[i, 1]
    for neighbor_id in neighbor_ids:
        if neighbor_id in nodes_dict:
            edge = nodes_dict[node_id].add_neighbor(nodes_dict[neighbor_id])
            edges_dict[edge.key] = edge

# %%
def is_on_line(p, line):
    nearest_point = line.interpolate(line.project(p))
    return nearest_point.distance(p) < 0.0001

edges = list(edges_dict.values())
lines = [e.line_string for e in edges_dict.values()]
lines_gs = gpd.GeoSeries(lines, crs=CRS_PLOT).to_crs(CRS_PLOT)

# %%
def crop(gdf, ax, x_bounds, y_bounds):
    minx, miny, maxx, maxy = gdf.geometry.total_bounds
    dx = maxx - minx
    dy = maxy - miny
    ax.set_xlim(minx + x_bounds[0] * dx, minx + x_bounds[1] * dx)
    ax.set_ylim(maxy - y_bounds[1] * dy, maxy - y_bounds[0] * dy)

fig, ax = plt.subplots(figsize=(15, 15))
crop(zips_gdf, ax, [0.0, 1.0], [0.2, 0.5])

zips_gdf.plot(ax=ax, color='lightgrey')
lines_gs.plot(ax=ax, color='grey')
route_gdf.plot(ax=ax, color='darkblue', markersize=5, zorder=2)

plt.show()

# %%
def get_min_distance(p, line):
    nearest_point = line.interpolate(line.project(p))
    return nearest_point.distance(p)

def get_nearest_edge(point):
    nearest_edge = edges[0]
    nearest_dist = 1
    for edge in edges:
        dist = get_min_distance(point, edge.line_string)
        if dist < nearest_dist:
            nearest_dist = dist
            nearest_edge = edge
    return nearest_edge

THRESHOLD = 0.0001
nearest_edges = []
for i in range(0, len(route_gdf)):
    point_row = route_gdf.iloc[i]
    point = Point(point_row.geometry.x, point_row.geometry.y)
    nearest_edges.append(get_nearest_edge(point))

# %%
nearest_edges_gs = gpd.GeoSeries([e.line_string for e in nearest_edges], crs=CRS_PLOT).to_crs(CRS_PLOT)

# %%
fig, ax = plt.subplots(figsize=(15, 15))
crop(zips_gdf, ax, [0.45, 0.55], [0.3, 0.4])
crop(zips_gdf, ax, [0.0, 1.0], [0.2, 0.5])
zips_gdf.plot(ax=ax, color='lightgrey')
nearest_edges_gs.plot(ax=ax, color='darkblue')
plt.show()

# %%
def dedup(item_list):
    item_set = set()
    items = []
    for item in item_list:
        if item in item_set:
            continue
        item_set.add(item)
        items.append(item)
    return items

nearest_edges_set = dedup(nearest_edges)

# %%
class Path:
    def __init__(self, edge, path=None):
        self.edges = deque([])
        if path != None:
            self.edges = path.edges.copy()
        self.edges.append(edge)
        
    def get_neighbors(self):
        neighbor_edges = self.get_end().edges
        return [Path(edge, path=self) for edge in neighbor_edges]
        
    def get_end(self):
        return self.edges[-1].node_to

all_edges = []
def bfs(edge1, edge2):
    source = edge1.node_from
    target = edge2.node_to
    
    queue = deque()
    node = source
    edges = source.edges
    path = Path(edge1)
    paths = [Path(e, path=path) for e in edges]
    queue.extend(paths)
    visited = set([source])
    
    all_edges.extend(edges)
    
    while len(queue) > 0:
        path = queue.popleft()
        node = path.get_end()
        
        if node in visited:
            continue
        if node == target:
            print('Found target')
            return path
        if len(queue) > 1000:
            print('Exceeded limit')
            print(edge1)
            print(edge2)
            break
        visited.add(node)
        
        all_edges.extend(node.edges)
        next_paths = path.get_neighbors()
        queue.extend(next_paths)
    print('queue empty', len(queue))

trajectory_edges = []
for i in range(0, len(nearest_edges_set) - 1):
    source_edge = nearest_edges_set[i]
    target_edge = nearest_edges_set[i + 1]
    
    path = bfs(source_edge, target_edge)
    if path == None:
        print(i)

    for edge in path.edges:
        trajectory_edges.append(edge)
    
trajectory_edges = dedup(trajectory_edges)
# Out:
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target
# Found target

# %%
def get_point_at(gdf, index):
    row = gdf.iloc[index]
    return Point(row.geometry.x, row.geometry.y)

point1 = get_point_at(route_gdf, 0)
point2 = get_point_at(route_gdf, 1)

edge1 = get_nearest_edge(point1)
edge2 = get_nearest_edge(point2)

edge1_gs = gpd.GeoSeries([edge1.line_string], crs=CRS_PLOT).to_crs(CRS_PLOT)
edge2_gs = gpd.GeoSeries([edge2.line_string], crs=CRS_PLOT).to_crs(CRS_PLOT)

trajectory_edges_gs = gpd.GeoSeries([e.line_string for e in trajectory_edges], crs=CRS_PLOT).to_crs(CRS_PLOT)

# %%
for e in path.edges:
    print(e.key)
# Out:
# 29153:29245
# 29153:29245
# 29245:70780
# 70780:29247
# 29247:102918
# 102918:9036160
# 9036160:29249
# 29249:79848
# 79848:29244
# 29244:80231

# %%
fig, ax = plt.subplots(figsize=(15, 15))
crop(zips_gdf, ax, [0.1, 0.9], [0.2, 0.4])
zips_gdf.plot(ax=ax, color='lightgrey')
lines_gs.plot(ax=ax, color='#aaa')
trajectory_edges_gs.plot(ax=ax, color='black')
route_gdf.plot(ax=ax, zorder=2, markersize=3)

# split 10-11

edge1_gs.plot(ax=ax, color='darkblue')
edge2_gs.plot(ax=ax, color='darkred')

ax.scatter(point1.x, point1.y, color='blue')
ax.scatter(point2.x, point2.y, color='red')

plt.show()

# %%
print(nearest_edges_set[9].key)
print(nearest_edges_set[10].key)
# Out:
# 93207:93199
# 15841:15844
